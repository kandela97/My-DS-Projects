# %% [markdown]
# ## Business Funding Data
#
# After Exploring the Business Funding Data.csv file, I observed that the data had a total of 11 columns and 26 entries with effective date, financial type and financial type normalized having the highest numbers of null values, the dataset showed a number of business funding round in Nigeria, their website domain, Investors, Investor counts, time of founding, categories and more. I imported the file using the pd.read_csv function using latin1 encoding.
#
# To clean, preprocess and transform the data, I first started by checking the percentage of missing values in each column using the isnull().sum()/ len(df) function, after which I checked the unique values of the highest missing value column (effective date). I had to drop the column as it was irrelevant and had a mode of Null, to the data.
#
# The mode of Financing type normalized which was seed, was used to replace the Nan Values in the column to avoid Null values and improve data quality. The financing type column was also dropped as it had a reoccurring value of NaN as a mode. Duplicate value was checked for as the data had 0 duplicate rows.
#
# For the Investors column, the mode (accelia.vc) was used to replace missing values using the fillna function. The mean of the investor count column was calculated and used to represent missing values in the investors count column.
#
# During Data Transformation, Label encoding was used on the website domain, financing type normalized, investors and categories column to transform categorical column to numeric using the sklearn preprocessing package Label Encoder.
#
# Using the MinMaxScaler standardization technique, the investors count column was scaled from a min and max of 1 and 9 to a min and max of 0 and 1 respectively. This was used over standardscaler as it gave a more appropriate range.
#
# It is important to preprocess data before real-world data analysis as it helps in handling mistakes due to human errors in terms of missing values, outliers, and duplicates which reduces data quality and integrity.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Business Funding Data.csv", encoding='latin1')
df.head()
# Out:
#   Website Domain Effective date                   Found At Financing Type  \
# 0  trafigura.com            NaN  2024-03-14T01:00:00+01:00            NaN
# 1     zenobe.com            NaN  2024-05-31T02:00:00+02:00            NaN
# 2     zenobe.com            NaN  2024-07-24T02:00:00+02:00            NaN
# 3      canva.com            NaN  2024-05-01T02:00:00+02:00            NaN
# 4   fidelity.com            NaN  2024-04-11T02:00:00+02:00            NaN
#
#   Financing Type Normalized          Categories  \
# 0                       NaN                  []
# 1                       NaN                  []
# 2                       NaN  ["private_equity"]
# 3                       NaN                  []
# 4                       NaN                  []
#
#                                            Investors  Investors Count  \
# 0                                                NaN              NaN
# 1  avivainvestors.com, lloydsbankinggroup.com, sa...              9.0
# 2                                                NaN              NaN
# 3                              stackcapitalgroup.com              1.0
# 4                                chevychasetrust.com              1.0
#
#            Amount  Amount Normalized  \
# 0           $1.9b         1900000000
# 1  $522.7 million          522700000
# 2          £41.7m           53671000
# 3    US$8 million            8000000
# 4   $1.96 million            1960000
#
#                                          Source Urls
# 0  https://www.tradefinanceglobal.com/posts/trafi...
# 1  https://realassets.ipe.com/news/aviva-among-le...
# 2  https://www.innovationnewsnetwork.com/zenobe-a...
# 3  https://www.globenewswire.com/news-release/202...
# 4  https://www.defenseworld.net/2024/04/11/chevy-...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Website Domain             26 non-null     object
#  1   Effective date             6 non-null      object
#  2   Found At                   26 non-null     object
#  3   Financing Type             8 non-null      object
#  4   Financing Type Normalized  8 non-null      object
#  5   Categories                 26 non-null     object
#  6   Investors                  13 non-null     object
#  7   Investors Count            13 non-null     float64
#  8   Amount                     26 non-null     object
#  9   Amount Normalized          26 non-null     int64
#  10  Source Urls                26 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 2.4+ KB

# %% [markdown]
# ## Missing Values

# %%
# Calculate percentage of missing values for each column
missing_percentage = df.isnull().sum() / len(df) * 100
missing_percentage
# Out:
# Website Domain                0.000000
# Effective date               76.923077
# Found At                      0.000000
# Financing Type               69.230769
# Financing Type Normalized    69.230769
# Categories                    0.000000
# Investors                    50.000000
# Investors Count              50.000000
# Amount                        0.000000
# Amount Normalized             0.000000
# Source Urls                   0.000000
# dtype: float64

# %%
df ['Effective date']. unique()
# Out:
# array([nan, '2024-04-18T02:00:00+02:00', '2024-04-16T02:00:00+02:00',
#        '2024-06-20T02:00:00+02:00', '2024-04-24T02:00:00+02:00',
#        '2024-06-26T02:00:00+02:00', '2024-06-27T02:00:00+02:00'],
#       dtype=object)

# %%
df ['Effective date'].mode(0)
# Out:
# 0    NaN
# Name: Effective date, dtype: object

# %% [markdown]
# ### Droping the Effective date column as it has the highest number of Null value

# %%
df.drop(columns= ["Effective date"], inplace= True )
df
# Out:
#          Website Domain                   Found At Financing Type  \
# 0         trafigura.com  2024-03-14T01:00:00+01:00            NaN
# 1            zenobe.com  2024-05-31T02:00:00+02:00            NaN
# 2            zenobe.com  2024-07-24T02:00:00+02:00            NaN
# 3             canva.com  2024-05-01T02:00:00+02:00            NaN
# 4          fidelity.com  2024-04-11T02:00:00+02:00            NaN
# 5       swtchenergy.com  2024-04-24T02:00:00+02:00       Series B
# 6            carnow.com  2024-04-16T02:00:00+02:00            NaN
# 7        databricks.com  2024-08-07T02:00:00+02:00       Series I
# 8         anthropic.com  2024-07-08T02:00:00+02:00            NaN
# 9                ey.com  2024-04-18T02:00:00+02:00            NaN
# 10          openpipe.ai  2024-03-26T01:00:00+01:00           Seed
# 11            canva.com  2024-05-09T02:00:00+02:00            NaN
# 12         syntetica.co  2024-07-16T02:00:00+02:00           Seed
# 13               zf.com  2024-07-15T02:00:00+02:00            NaN
# 14        sparelabs.com  2024-06-05T02:00:00+02:00            NaN
# 15            e-zinc.ca  2024-06-27T02:00:00+02:00      Series A2
# 16  biointelligence.com  2024-04-25T02:00:00+02:00            NaN
# 17  claritisoftware.com  2024-04-10T02:00:00+02:00            NaN
# 18          heylist.com  2024-06-18T02:00:00+02:00            NaN
# 19           qohash.com  2024-04-24T02:00:00+02:00            NaN
# 20        topicflow.com  2024-06-25T02:00:00+02:00           Seed
# 21  claritisoftware.com  2024-06-26T02:00:00+02:00            NaN
# 22  biointelligence.com  2024-04-30T02:00:00+02:00           Seed
# 23            gaiia.com  2024-06-27T02:00:00+02:00       Series A
# 24       sinnstudio.com  2024-05-22T02:00:00+02:00            NaN
# 25        topicflow.com  2024-06-25T02:00:00+02:00            NaN
#
#    Financing Type Normalized                     Categories  \
# 0                        NaN                             []
# 1                        NaN                             []
# 2                        NaN             ["private_equity"]
# 3                        NaN                             []
# 4                        NaN                             []
# 5                   series_b        ["series_b", "venture"]
# 6                        NaN             ["debt_financing"]
# 7                   series_i        ["series_i", "venture"]
# 8                        NaN                             []
# 9                        NaN                             []
# 10                      seed            ["seed", "venture"]
# 11                       NaN                             []
# 12                      seed            ["seed", "venture"]
# 13                       NaN                             []
# 14                       NaN                             []
# 15                 series_a2       ["series_a2", "venture"]
# 16                       NaN                             []
# 17                       NaN             ["private_equity"]
# 18                       NaN             ["private_equity"]
# 19                       NaN             ["private_equity"]
# 20                      seed            ["seed", "venture"]
# 21                       NaN             ["private_equity"]
# 22                      seed            ["seed", "venture"]
# 23                  series_a        ["series_a", "venture"]
# 24                       NaN  ["private_equity", "venture"]
# 25                       NaN                             []
#
#                                             Investors  Investors Count  \
# 0                                                 NaN              NaN
# 1   avivainvestors.com, lloydsbankinggroup.com, sa...              9.0
# 2                                                 NaN              NaN
# 3                               stackcapitalgroup.com              1.0
# 4                                 chevychasetrust.com              1.0
# 5                      alantra.com, blueearth.capital              2.0
# 6                                    runwaygrowth.com              1.0
# 7                                                 NaN              NaN
# 8                           damachotelsandresorts.com              1.0
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                        surocap.com              1.0
# 12                                                NaN              NaN
# 13                                            eib.org              1.0
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                  vistaragrowth.com              1.0
# 18                                         accelia.vc              1.0
# 19        edc.ca, desjardinscapital.com, fondsftq.com              3.0
# 20                                                NaN              NaN
# 21                                           cibc.com              1.0
# 22                                                NaN              NaN
# 23                                          inovia.vc              1.0
# 24                                                NaN              NaN
# 25                                                NaN              NaN
#
#                Amount  Amount Normalized  \
# 0               $1.9b         1900000000
# 1      $522.7 million          522700000
# 2              £41.7m           53671000
# 3        US$8 million            8000000
# 4       $1.96 million            1960000
# 5       $27.2 Million           27200000
# 6         $40 million           40000000
# 7        $685 million          685000000
# 8               $50mn           50000000
# 9            AU$10.7M            6865000
# 10       $6.7 million            6700000
# 11         $2 billion         2000000000
# 12       Û4.2 million            4581000
# 13       Û425 million          464695000
# 14               $10M           10000000
# 15            USD 31M           31000000
# 16                $5M            5000000
# 17  $24.6 million CAD           18139000
# 18              $1.6M            1600000
# 19      $17.4 million           17400000
# 20           CAD$2.5M            1823000
# 21        $10 million           10000000
# 22     $5 million CAD            3653000
# 23           US$13.2M           13200000
# 24              $2.5M            2500000
# 25              $2.5m            2500000
#
#                                           Source Urls
# 0   https://www.tradefinanceglobal.com/posts/trafi...
# 1   https://realassets.ipe.com/news/aviva-among-le...
# 2   https://www.innovationnewsnetwork.com/zenobe-a...
# 3   https://www.globenewswire.com/news-release/202...
# 4   https://www.defenseworld.net/2024/04/11/chevy-...
# 5   https://www.mercomindia.com/funding-and-ma-rou...
# 6   https://www.prnewswire.com/news-releases/runwa...
# 7   https://iteuropa.com/news/large-language-model...
# 8   https://www.arabianbusiness.com/industries/tec...
# 9   https://www.biometricupdate.com/202404/ey-secu...
# 10  https://www.geekwire.com/2024/seattle-startup-...
# 11  https://www.investing.com/news/stock-market-ne...
# 12  https://tech.eu/2024/07/16/syntetica-raises-eu...
# 13  https://thebrakereport.com/eib-funds-zf-brakin...
# 14  https://www.finsmes.com/2024/06/spare-receives...
# 15  https://www.explorebit.io/article/e-Zinc%20Rai...
# 16  https://www.prweb.com/releases/biointelligence...
# 17  https://betakit.com/government-software-provid...
# 18  https://www.newswire.ca/news-releases/heylist-...
# 19  https://qohash.com/qohash-secures-17-4-million...
# 20  https://www.finsmes.com/2024/06/topicflow-rais...
# 21  https://www.marketscreener.com/quote/stock/CAN...
# 22  https://betakit.com/biointelligence-technologi...
# 23  https://financialpost.com/globe-newswire/gaiia...
# 24  https://www.finsmes.com/2024/05/sinn-studio-ra...
# 25  https://www.streetinsider.com/Accesswire/Topic...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Website Domain             26 non-null     object
#  1   Found At                   26 non-null     object
#  2   Financing Type             8 non-null      object
#  3   Financing Type Normalized  8 non-null      object
#  4   Categories                 26 non-null     object
#  5   Investors                  13 non-null     object
#  6   Investors Count            13 non-null     float64
#  7   Amount                     26 non-null     object
#  8   Amount Normalized          26 non-null     int64
#  9   Source Urls                26 non-null     object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 2.2+ KB

# %%
df['Financing Type'].unique()
# Out:
# array([nan, 'Series B', 'Series I', 'Seed', 'Series A2', 'Series A'],
#       dtype=object)

# %%
df ['Financing Type'].mode(0)
# Out:
# 0    NaN
# Name: Financing Type, dtype: object

# %%
df ['Financing Type Normalized'].mode()
# Out:
# 0    seed
# Name: Financing Type Normalized, dtype: object

# %% [markdown]
# ### Replacing Nan values of "Financing Type Normalized" column with the mode

# %%
df['Financing Type Normalized'].fillna(df['Financing Type Normalized'].mode()[0], inplace=True)
df
# Out:
#          Website Domain                   Found At Financing Type  \
# 0         trafigura.com  2024-03-14T01:00:00+01:00            NaN
# 1            zenobe.com  2024-05-31T02:00:00+02:00            NaN
# 2            zenobe.com  2024-07-24T02:00:00+02:00            NaN
# 3             canva.com  2024-05-01T02:00:00+02:00            NaN
# 4          fidelity.com  2024-04-11T02:00:00+02:00            NaN
# 5       swtchenergy.com  2024-04-24T02:00:00+02:00       Series B
# 6            carnow.com  2024-04-16T02:00:00+02:00            NaN
# 7        databricks.com  2024-08-07T02:00:00+02:00       Series I
# 8         anthropic.com  2024-07-08T02:00:00+02:00            NaN
# 9                ey.com  2024-04-18T02:00:00+02:00            NaN
# 10          openpipe.ai  2024-03-26T01:00:00+01:00           Seed
# 11            canva.com  2024-05-09T02:00:00+02:00            NaN
# 12         syntetica.co  2024-07-16T02:00:00+02:00           Seed
# 13               zf.com  2024-07-15T02:00:00+02:00            NaN
# 14        sparelabs.com  2024-06-05T02:00:00+02:00            NaN
# 15            e-zinc.ca  2024-06-27T02:00:00+02:00      Series A2
# 16  biointelligence.com  2024-04-25T02:00:00+02:00            NaN
# 17  claritisoftware.com  2024-04-10T02:00:00+02:00            NaN
# 18          heylist.com  2024-06-18T02:00:00+02:00            NaN
# 19           qohash.com  2024-04-24T02:00:00+02:00            NaN
# 20        topicflow.com  2024-06-25T02:00:00+02:00           Seed
# 21  claritisoftware.com  2024-06-26T02:00:00+02:00            NaN
# 22  biointelligence.com  2024-04-30T02:00:00+02:00           Seed
# 23            gaiia.com  2024-06-27T02:00:00+02:00       Series A
# 24       sinnstudio.com  2024-05-22T02:00:00+02:00            NaN
# 25        topicflow.com  2024-06-25T02:00:00+02:00            NaN
#
#    Financing Type Normalized                     Categories  \
# 0                       seed                             []
# 1                       seed                             []
# 2                       seed             ["private_equity"]
# 3                       seed                             []
# 4                       seed                             []
# 5                   series_b        ["series_b", "venture"]
# 6                       seed             ["debt_financing"]
# 7                   series_i        ["series_i", "venture"]
# 8                       seed                             []
# 9                       seed                             []
# 10                      seed            ["seed", "venture"]
# 11                      seed                             []
# 12                      seed            ["seed", "venture"]
# 13                      seed                             []
# 14                      seed                             []
# 15                 series_a2       ["series_a2", "venture"]
# 16                      seed                             []
# 17                      seed             ["private_equity"]
# 18                      seed             ["private_equity"]
# 19                      seed             ["private_equity"]
# 20                      seed            ["seed", "venture"]
# 21                      seed             ["private_equity"]
# 22                      seed            ["seed", "venture"]
# 23                  series_a        ["series_a", "venture"]
# 24                      seed  ["private_equity", "venture"]
# 25                      seed                             []
#
#                                             Investors  Investors Count  \
# 0                                                 NaN              NaN
# 1   avivainvestors.com, lloydsbankinggroup.com, sa...              9.0
# 2                                                 NaN              NaN
# 3                               stackcapitalgroup.com              1.0
# 4                                 chevychasetrust.com              1.0
# 5                      alantra.com, blueearth.capital              2.0
# 6                                    runwaygrowth.com              1.0
# 7                                                 NaN              NaN
# 8                           damachotelsandresorts.com              1.0
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                        surocap.com              1.0
# 12                                                NaN              NaN
# 13                                            eib.org              1.0
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                  vistaragrowth.com              1.0
# 18                                         accelia.vc              1.0
# 19        edc.ca, desjardinscapital.com, fondsftq.com              3.0
# 20                                                NaN              NaN
# 21                                           cibc.com              1.0
# 22                                                NaN              NaN
# 23                                          inovia.vc              1.0
# 24                                                NaN              NaN
# 25                                                NaN              NaN
#
#                Amount  Amount Normalized  \
# 0               $1.9b         1900000000
# 1      $522.7 million          522700000
# 2              £41.7m           53671000
# 3        US$8 million            8000000
# 4       $1.96 million            1960000
# 5       $27.2 Million           27200000
# 6         $40 million           40000000
# 7        $685 million          685000000
# 8               $50mn           50000000
# 9            AU$10.7M            6865000
# 10       $6.7 million            6700000
# 11         $2 billion         2000000000
# 12       Û4.2 million            4581000
# 13       Û425 million          464695000
# 14               $10M           10000000
# 15            USD 31M           31000000
# 16                $5M            5000000
# 17  $24.6 million CAD           18139000
# 18              $1.6M            1600000
# 19      $17.4 million           17400000
# 20           CAD$2.5M            1823000
# 21        $10 million           10000000
# 22     $5 million CAD            3653000
# 23           US$13.2M           13200000
# 24              $2.5M            2500000
# 25              $2.5m            2500000
#
#                                           Source Urls
# 0   https://www.tradefinanceglobal.com/posts/trafi...
# 1   https://realassets.ipe.com/news/aviva-among-le...
# 2   https://www.innovationnewsnetwork.com/zenobe-a...
# 3   https://www.globenewswire.com/news-release/202...
# 4   https://www.defenseworld.net/2024/04/11/chevy-...
# 5   https://www.mercomindia.com/funding-and-ma-rou...
# 6   https://www.prnewswire.com/news-releases/runwa...
# 7   https://iteuropa.com/news/large-language-model...
# 8   https://www.arabianbusiness.com/industries/tec...
# 9   https://www.biometricupdate.com/202404/ey-secu...
# 10  https://www.geekwire.com/2024/seattle-startup-...
# 11  https://www.investing.com/news/stock-market-ne...
# 12  https://tech.eu/2024/07/16/syntetica-raises-eu...
# 13  https://thebrakereport.com/eib-funds-zf-brakin...
# 14  https://www.finsmes.com/2024/06/spare-receives...
# 15  https://www.explorebit.io/article/e-Zinc%20Rai...
# 16  https://www.prweb.com/releases/biointelligence...
# 17  https://betakit.com/government-software-provid...
# 18  https://www.newswire.ca/news-releases/heylist-...
# 19  https://qohash.com/qohash-secures-17-4-million...
# 20  https://www.finsmes.com/2024/06/topicflow-rais...
# 21  https://www.marketscreener.com/quote/stock/CAN...
# 22  https://betakit.com/biointelligence-technologi...
# 23  https://financialpost.com/globe-newswire/gaiia...
# 24  https://www.finsmes.com/2024/05/sinn-studio-ra...
# 25  https://www.streetinsider.com/Accesswire/Topic...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Website Domain             26 non-null     object
#  1   Found At                   26 non-null     object
#  2   Financing Type             8 non-null      object
#  3   Financing Type Normalized  26 non-null     object
#  4   Categories                 26 non-null     object
#  5   Investors                  13 non-null     object
#  6   Investors Count            13 non-null     float64
#  7   Amount                     26 non-null     object
#  8   Amount Normalized          26 non-null     int64
#  9   Source Urls                26 non-null     object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 2.2+ KB

# %% [markdown]
# ### Dropping Financing Type column

# %%
df.drop(columns=['Financing Type'], inplace=True)
df
# Out:
#          Website Domain                   Found At Financing Type Normalized  \
# 0         trafigura.com  2024-03-14T01:00:00+01:00                      seed
# 1            zenobe.com  2024-05-31T02:00:00+02:00                      seed
# 2            zenobe.com  2024-07-24T02:00:00+02:00                      seed
# 3             canva.com  2024-05-01T02:00:00+02:00                      seed
# 4          fidelity.com  2024-04-11T02:00:00+02:00                      seed
# 5       swtchenergy.com  2024-04-24T02:00:00+02:00                  series_b
# 6            carnow.com  2024-04-16T02:00:00+02:00                      seed
# 7        databricks.com  2024-08-07T02:00:00+02:00                  series_i
# 8         anthropic.com  2024-07-08T02:00:00+02:00                      seed
# 9                ey.com  2024-04-18T02:00:00+02:00                      seed
# 10          openpipe.ai  2024-03-26T01:00:00+01:00                      seed
# 11            canva.com  2024-05-09T02:00:00+02:00                      seed
# 12         syntetica.co  2024-07-16T02:00:00+02:00                      seed
# 13               zf.com  2024-07-15T02:00:00+02:00                      seed
# 14        sparelabs.com  2024-06-05T02:00:00+02:00                      seed
# 15            e-zinc.ca  2024-06-27T02:00:00+02:00                 series_a2
# 16  biointelligence.com  2024-04-25T02:00:00+02:00                      seed
# 17  claritisoftware.com  2024-04-10T02:00:00+02:00                      seed
# 18          heylist.com  2024-06-18T02:00:00+02:00                      seed
# 19           qohash.com  2024-04-24T02:00:00+02:00                      seed
# 20        topicflow.com  2024-06-25T02:00:00+02:00                      seed
# 21  claritisoftware.com  2024-06-26T02:00:00+02:00                      seed
# 22  biointelligence.com  2024-04-30T02:00:00+02:00                      seed
# 23            gaiia.com  2024-06-27T02:00:00+02:00                  series_a
# 24       sinnstudio.com  2024-05-22T02:00:00+02:00                      seed
# 25        topicflow.com  2024-06-25T02:00:00+02:00                      seed
#
#                        Categories  \
# 0                              []
# 1                              []
# 2              ["private_equity"]
# 3                              []
# 4                              []
# 5         ["series_b", "venture"]
# 6              ["debt_financing"]
# 7         ["series_i", "venture"]
# 8                              []
# 9                              []
# 10            ["seed", "venture"]
# 11                             []
# 12            ["seed", "venture"]
# 13                             []
# 14                             []
# 15       ["series_a2", "venture"]
# 16                             []
# 17             ["private_equity"]
# 18             ["private_equity"]
# 19             ["private_equity"]
# 20            ["seed", "venture"]
# 21             ["private_equity"]
# 22            ["seed", "venture"]
# 23        ["series_a", "venture"]
# 24  ["private_equity", "venture"]
# 25                             []
#
#                                             Investors  Investors Count  \
# 0                                                 NaN              NaN
# 1   avivainvestors.com, lloydsbankinggroup.com, sa...              9.0
# 2                                                 NaN              NaN
# 3                               stackcapitalgroup.com              1.0
# 4                                 chevychasetrust.com              1.0
# 5                      alantra.com, blueearth.capital              2.0
# 6                                    runwaygrowth.com              1.0
# 7                                                 NaN              NaN
# 8                           damachotelsandresorts.com              1.0
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                        surocap.com              1.0
# 12                                                NaN              NaN
# 13                                            eib.org              1.0
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                  vistaragrowth.com              1.0
# 18                                         accelia.vc              1.0
# 19        edc.ca, desjardinscapital.com, fondsftq.com              3.0
# 20                                                NaN              NaN
# 21                                           cibc.com              1.0
# 22                                                NaN              NaN
# 23                                          inovia.vc              1.0
# 24                                                NaN              NaN
# 25                                                NaN              NaN
#
#                Amount  Amount Normalized  \
# 0               $1.9b         1900000000
# 1      $522.7 million          522700000
# 2              £41.7m           53671000
# 3        US$8 million            8000000
# 4       $1.96 million            1960000
# 5       $27.2 Million           27200000
# 6         $40 million           40000000
# 7        $685 million          685000000
# 8               $50mn           50000000
# 9            AU$10.7M            6865000
# 10       $6.7 million            6700000
# 11         $2 billion         2000000000
# 12       Û4.2 million            4581000
# 13       Û425 million          464695000
# 14               $10M           10000000
# 15            USD 31M           31000000
# 16                $5M            5000000
# 17  $24.6 million CAD           18139000
# 18              $1.6M            1600000
# 19      $17.4 million           17400000
# 20           CAD$2.5M            1823000
# 21        $10 million           10000000
# 22     $5 million CAD            3653000
# 23           US$13.2M           13200000
# 24              $2.5M            2500000
# 25              $2.5m            2500000
#
#                                           Source Urls
# 0   https://www.tradefinanceglobal.com/posts/trafi...
# 1   https://realassets.ipe.com/news/aviva-among-le...
# 2   https://www.innovationnewsnetwork.com/zenobe-a...
# 3   https://www.globenewswire.com/news-release/202...
# 4   https://www.defenseworld.net/2024/04/11/chevy-...
# 5   https://www.mercomindia.com/funding-and-ma-rou...
# 6   https://www.prnewswire.com/news-releases/runwa...
# 7   https://iteuropa.com/news/large-language-model...
# 8   https://www.arabianbusiness.com/industries/tec...
# 9   https://www.biometricupdate.com/202404/ey-secu...
# 10  https://www.geekwire.com/2024/seattle-startup-...
# 11  https://www.investing.com/news/stock-market-ne...
# 12  https://tech.eu/2024/07/16/syntetica-raises-eu...
# 13  https://thebrakereport.com/eib-funds-zf-brakin...
# 14  https://www.finsmes.com/2024/06/spare-receives...
# 15  https://www.explorebit.io/article/e-Zinc%20Rai...
# 16  https://www.prweb.com/releases/biointelligence...
# 17  https://betakit.com/government-software-provid...
# 18  https://www.newswire.ca/news-releases/heylist-...
# 19  https://qohash.com/qohash-secures-17-4-million...
# 20  https://www.finsmes.com/2024/06/topicflow-rais...
# 21  https://www.marketscreener.com/quote/stock/CAN...
# 22  https://betakit.com/biointelligence-technologi...
# 23  https://financialpost.com/globe-newswire/gaiia...
# 24  https://www.finsmes.com/2024/05/sinn-studio-ra...
# 25  https://www.streetinsider.com/Accesswire/Topic...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Website Domain             26 non-null     object
#  1   Found At                   26 non-null     object
#  2   Financing Type Normalized  26 non-null     object
#  3   Categories                 26 non-null     object
#  4   Investors                  13 non-null     object
#  5   Investors Count            13 non-null     float64
#  6   Amount                     26 non-null     object
#  7   Amount Normalized          26 non-null     int64
#  8   Source Urls                26 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.0+ KB

# %% [markdown]
# Checking for Duplicates

# %%
duplicate = df.duplicated().sum()
print (f"\nNumber of duplicate rows: {duplicate}")
# Out:
# Number of duplicate rows: 0

# %%
df.head(10)
# Out:
#     Website Domain                   Found At Financing Type Normalized  \
# 0    trafigura.com  2024-03-14T01:00:00+01:00                      seed
# 1       zenobe.com  2024-05-31T02:00:00+02:00                      seed
# 2       zenobe.com  2024-07-24T02:00:00+02:00                      seed
# 3        canva.com  2024-05-01T02:00:00+02:00                      seed
# 4     fidelity.com  2024-04-11T02:00:00+02:00                      seed
# 5  swtchenergy.com  2024-04-24T02:00:00+02:00                  series_b
# 6       carnow.com  2024-04-16T02:00:00+02:00                      seed
# 7   databricks.com  2024-08-07T02:00:00+02:00                  series_i
# 8    anthropic.com  2024-07-08T02:00:00+02:00                      seed
# 9           ey.com  2024-04-18T02:00:00+02:00                      seed
#
#                 Categories                                          Investors  \
# 0                       []                                                NaN
# 1                       []  avivainvestors.com, lloydsbankinggroup.com, sa...
# 2       ["private_equity"]                                                NaN
# 3                       []                              stackcapitalgroup.com
# 4                       []                                chevychasetrust.com
# 5  ["series_b", "venture"]                     alantra.com, blueearth.capital
# 6       ["debt_financing"]                                   runwaygrowth.com
# 7  ["series_i", "venture"]                                                NaN
# 8                       []                          damachotelsandresorts.com
# 9                       []                                                NaN
#
#    Investors Count          Amount  Amount Normalized  \
# 0              NaN           $1.9b         1900000000
# 1              9.0  $522.7 million          522700000
# 2              NaN          £41.7m           53671000
# 3              1.0    US$8 million            8000000
# 4              1.0   $1.96 million            1960000
# 5              2.0   $27.2 Million           27200000
# 6              1.0     $40 million           40000000
# 7              NaN    $685 million          685000000
# 8              1.0           $50mn           50000000
# 9              NaN        AU$10.7M            6865000
#
#                                          Source Urls
# 0  https://www.tradefinanceglobal.com/posts/trafi...
# 1  https://realassets.ipe.com/news/aviva-among-le...
# 2  https://www.innovationnewsnetwork.com/zenobe-a...
# 3  https://www.globenewswire.com/news-release/202...
# 4  https://www.defenseworld.net/2024/04/11/chevy-...
# 5  https://www.mercomindia.com/funding-and-ma-rou...
# 6  https://www.prnewswire.com/news-releases/runwa...
# 7  https://iteuropa.com/news/large-language-model...
# 8  https://www.arabianbusiness.com/industries/tec...
# 9  https://www.biometricupdate.com/202404/ey-secu...

# %%
df ['Investors'].unique()
# Out:
# array([nan,
#        'avivainvestors.com, lloydsbankinggroup.com, santander.co.uk, swip.com, cibc.com, societegenerale.com, natwest.us, rabobank.com, mufg.jp',
#        'stackcapitalgroup.com', 'chevychasetrust.com',
#        'alantra.com, blueearth.capital', 'runwaygrowth.com',
#        'damachotelsandresorts.com', 'surocap.com', 'eib.org',
#        'vistaragrowth.com', 'accelia.vc',
#        'edc.ca, desjardinscapital.com, fondsftq.com', 'cibc.com',
#        'inovia.vc'], dtype=object)

# %%
df ['Investors'].mode()[0]
# Out:
# 'accelia.vc'

# %%
df ['Investors']. fillna(df['Investors'].mode()[0], inplace=True)
df
# Out:
#          Website Domain                   Found At Financing Type Normalized  \
# 0         trafigura.com  2024-03-14T01:00:00+01:00                      seed
# 1            zenobe.com  2024-05-31T02:00:00+02:00                      seed
# 2            zenobe.com  2024-07-24T02:00:00+02:00                      seed
# 3             canva.com  2024-05-01T02:00:00+02:00                      seed
# 4          fidelity.com  2024-04-11T02:00:00+02:00                      seed
# 5       swtchenergy.com  2024-04-24T02:00:00+02:00                  series_b
# 6            carnow.com  2024-04-16T02:00:00+02:00                      seed
# 7        databricks.com  2024-08-07T02:00:00+02:00                  series_i
# 8         anthropic.com  2024-07-08T02:00:00+02:00                      seed
# 9                ey.com  2024-04-18T02:00:00+02:00                      seed
# 10          openpipe.ai  2024-03-26T01:00:00+01:00                      seed
# 11            canva.com  2024-05-09T02:00:00+02:00                      seed
# 12         syntetica.co  2024-07-16T02:00:00+02:00                      seed
# 13               zf.com  2024-07-15T02:00:00+02:00                      seed
# 14        sparelabs.com  2024-06-05T02:00:00+02:00                      seed
# 15            e-zinc.ca  2024-06-27T02:00:00+02:00                 series_a2
# 16  biointelligence.com  2024-04-25T02:00:00+02:00                      seed
# 17  claritisoftware.com  2024-04-10T02:00:00+02:00                      seed
# 18          heylist.com  2024-06-18T02:00:00+02:00                      seed
# 19           qohash.com  2024-04-24T02:00:00+02:00                      seed
# 20        topicflow.com  2024-06-25T02:00:00+02:00                      seed
# 21  claritisoftware.com  2024-06-26T02:00:00+02:00                      seed
# 22  biointelligence.com  2024-04-30T02:00:00+02:00                      seed
# 23            gaiia.com  2024-06-27T02:00:00+02:00                  series_a
# 24       sinnstudio.com  2024-05-22T02:00:00+02:00                      seed
# 25        topicflow.com  2024-06-25T02:00:00+02:00                      seed
#
#                        Categories  \
# 0                              []
# 1                              []
# 2              ["private_equity"]
# 3                              []
# 4                              []
# 5         ["series_b", "venture"]
# 6              ["debt_financing"]
# 7         ["series_i", "venture"]
# 8                              []
# 9                              []
# 10            ["seed", "venture"]
# 11                             []
# 12            ["seed", "venture"]
# 13                             []
# 14                             []
# 15       ["series_a2", "venture"]
# 16                             []
# 17             ["private_equity"]
# 18             ["private_equity"]
# 19             ["private_equity"]
# 20            ["seed", "venture"]
# 21             ["private_equity"]
# 22            ["seed", "venture"]
# 23        ["series_a", "venture"]
# 24  ["private_equity", "venture"]
# 25                             []
#
#                                             Investors  Investors Count  \
# 0                                          accelia.vc              NaN
# 1   avivainvestors.com, lloydsbankinggroup.com, sa...              9.0
# 2                                          accelia.vc              NaN
# 3                               stackcapitalgroup.com              1.0
# 4                                 chevychasetrust.com              1.0
# 5                      alantra.com, blueearth.capital              2.0
# 6                                    runwaygrowth.com              1.0
# 7                                          accelia.vc              NaN
# 8                           damachotelsandresorts.com              1.0
# 9                                          accelia.vc              NaN
# 10                                         accelia.vc              NaN
# 11                                        surocap.com              1.0
# 12                                         accelia.vc              NaN
# 13                                            eib.org              1.0
# 14                                         accelia.vc              NaN
# 15                                         accelia.vc              NaN
# 16                                         accelia.vc              NaN
# 17                                  vistaragrowth.com              1.0
# 18                                         accelia.vc              1.0
# 19        edc.ca, desjardinscapital.com, fondsftq.com              3.0
# 20                                         accelia.vc              NaN
# 21                                           cibc.com              1.0
# 22                                         accelia.vc              NaN
# 23                                          inovia.vc              1.0
# 24                                         accelia.vc              NaN
# 25                                         accelia.vc              NaN
#
#                Amount  Amount Normalized  \
# 0               $1.9b         1900000000
# 1      $522.7 million          522700000
# 2              £41.7m           53671000
# 3        US$8 million            8000000
# 4       $1.96 million            1960000
# 5       $27.2 Million           27200000
# 6         $40 million           40000000
# 7        $685 million          685000000
# 8               $50mn           50000000
# 9            AU$10.7M            6865000
# 10       $6.7 million            6700000
# 11         $2 billion         2000000000
# 12       Û4.2 million            4581000
# 13       Û425 million          464695000
# 14               $10M           10000000
# 15            USD 31M           31000000
# 16                $5M            5000000
# 17  $24.6 million CAD           18139000
# 18              $1.6M            1600000
# 19      $17.4 million           17400000
# 20           CAD$2.5M            1823000
# 21        $10 million           10000000
# 22     $5 million CAD            3653000
# 23           US$13.2M           13200000
# 24              $2.5M            2500000
# 25              $2.5m            2500000
#
#                                           Source Urls
# 0   https://www.tradefinanceglobal.com/posts/trafi...
# 1   https://realassets.ipe.com/news/aviva-among-le...
# 2   https://www.innovationnewsnetwork.com/zenobe-a...
# 3   https://www.globenewswire.com/news-release/202...
# 4   https://www.defenseworld.net/2024/04/11/chevy-...
# 5   https://www.mercomindia.com/funding-and-ma-rou...
# 6   https://www.prnewswire.com/news-releases/runwa...
# 7   https://iteuropa.com/news/large-language-model...
# 8   https://www.arabianbusiness.com/industries/tec...
# 9   https://www.biometricupdate.com/202404/ey-secu...
# 10  https://www.geekwire.com/2024/seattle-startup-...
# 11  https://www.investing.com/news/stock-market-ne...
# 12  https://tech.eu/2024/07/16/syntetica-raises-eu...
# 13  https://thebrakereport.com/eib-funds-zf-brakin...
# 14  https://www.finsmes.com/2024/06/spare-receives...
# 15  https://www.explorebit.io/article/e-Zinc%20Rai...
# 16  https://www.prweb.com/releases/biointelligence...
# 17  https://betakit.com/government-software-provid...
# 18  https://www.newswire.ca/news-releases/heylist-...
# 19  https://qohash.com/qohash-secures-17-4-million...
# 20  https://www.finsmes.com/2024/06/topicflow-rais...
# 21  https://www.marketscreener.com/quote/stock/CAN...
# 22  https://betakit.com/biointelligence-technologi...
# 23  https://financialpost.com/globe-newswire/gaiia...
# 24  https://www.finsmes.com/2024/05/sinn-studio-ra...
# 25  https://www.streetinsider.com/Accesswire/Topic...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Website Domain             26 non-null     object
#  1   Found At                   26 non-null     object
#  2   Financing Type Normalized  26 non-null     object
#  3   Categories                 26 non-null     object
#  4   Investors                  26 non-null     object
#  5   Investors Count            13 non-null     float64
#  6   Amount                     26 non-null     object
#  7   Amount Normalized          26 non-null     int64
#  8   Source Urls                26 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.0+ KB

# %%
df ['Investors Count']. mean()
# Out:
# 1.8461538461538463

# %%
df ['Investors Count']. fillna(df ['Investors Count'].mean(), inplace=True)
df
# Out:
#          Website Domain                   Found At Financing Type Normalized  \
# 0         trafigura.com  2024-03-14T01:00:00+01:00                      seed
# 1            zenobe.com  2024-05-31T02:00:00+02:00                      seed
# 2            zenobe.com  2024-07-24T02:00:00+02:00                      seed
# 3             canva.com  2024-05-01T02:00:00+02:00                      seed
# 4          fidelity.com  2024-04-11T02:00:00+02:00                      seed
# 5       swtchenergy.com  2024-04-24T02:00:00+02:00                  series_b
# 6            carnow.com  2024-04-16T02:00:00+02:00                      seed
# 7        databricks.com  2024-08-07T02:00:00+02:00                  series_i
# 8         anthropic.com  2024-07-08T02:00:00+02:00                      seed
# 9                ey.com  2024-04-18T02:00:00+02:00                      seed
# 10          openpipe.ai  2024-03-26T01:00:00+01:00                      seed
# 11            canva.com  2024-05-09T02:00:00+02:00                      seed
# 12         syntetica.co  2024-07-16T02:00:00+02:00                      seed
# 13               zf.com  2024-07-15T02:00:00+02:00                      seed
# 14        sparelabs.com  2024-06-05T02:00:00+02:00                      seed
# 15            e-zinc.ca  2024-06-27T02:00:00+02:00                 series_a2
# 16  biointelligence.com  2024-04-25T02:00:00+02:00                      seed
# 17  claritisoftware.com  2024-04-10T02:00:00+02:00                      seed
# 18          heylist.com  2024-06-18T02:00:00+02:00                      seed
# 19           qohash.com  2024-04-24T02:00:00+02:00                      seed
# 20        topicflow.com  2024-06-25T02:00:00+02:00                      seed
# 21  claritisoftware.com  2024-06-26T02:00:00+02:00                      seed
# 22  biointelligence.com  2024-04-30T02:00:00+02:00                      seed
# 23            gaiia.com  2024-06-27T02:00:00+02:00                  series_a
# 24       sinnstudio.com  2024-05-22T02:00:00+02:00                      seed
# 25        topicflow.com  2024-06-25T02:00:00+02:00                      seed
#
#                        Categories  \
# 0                              []
# 1                              []
# 2              ["private_equity"]
# 3                              []
# 4                              []
# 5         ["series_b", "venture"]
# 6              ["debt_financing"]
# 7         ["series_i", "venture"]
# 8                              []
# 9                              []
# 10            ["seed", "venture"]
# 11                             []
# 12            ["seed", "venture"]
# 13                             []
# 14                             []
# 15       ["series_a2", "venture"]
# 16                             []
# 17             ["private_equity"]
# 18             ["private_equity"]
# 19             ["private_equity"]
# 20            ["seed", "venture"]
# 21             ["private_equity"]
# 22            ["seed", "venture"]
# 23        ["series_a", "venture"]
# 24  ["private_equity", "venture"]
# 25                             []
#
#                                             Investors  Investors Count  \
# 0                                          accelia.vc         1.846154
# 1   avivainvestors.com, lloydsbankinggroup.com, sa...         9.000000
# 2                                          accelia.vc         1.846154
# 3                               stackcapitalgroup.com         1.000000
# 4                                 chevychasetrust.com         1.000000
# 5                      alantra.com, blueearth.capital         2.000000
# 6                                    runwaygrowth.com         1.000000
# 7                                          accelia.vc         1.846154
# 8                           damachotelsandresorts.com         1.000000
# 9                                          accelia.vc         1.846154
# 10                                         accelia.vc         1.846154
# 11                                        surocap.com         1.000000
# 12                                         accelia.vc         1.846154
# 13                                            eib.org         1.000000
# 14                                         accelia.vc         1.846154
# 15                                         accelia.vc         1.846154
# 16                                         accelia.vc         1.846154
# 17                                  vistaragrowth.com         1.000000
# 18                                         accelia.vc         1.000000
# 19        edc.ca, desjardinscapital.com, fondsftq.com         3.000000
# 20                                         accelia.vc         1.846154
# 21                                           cibc.com         1.000000
# 22                                         accelia.vc         1.846154
# 23                                          inovia.vc         1.000000
# 24                                         accelia.vc         1.846154
# 25                                         accelia.vc         1.846154
#
#                Amount  Amount Normalized  \
# 0               $1.9b         1900000000
# 1      $522.7 million          522700000
# 2              £41.7m           53671000
# 3        US$8 million            8000000
# 4       $1.96 million            1960000
# 5       $27.2 Million           27200000
# 6         $40 million           40000000
# 7        $685 million          685000000
# 8               $50mn           50000000
# 9            AU$10.7M            6865000
# 10       $6.7 million            6700000
# 11         $2 billion         2000000000
# 12       Û4.2 million            4581000
# 13       Û425 million          464695000
# 14               $10M           10000000
# 15            USD 31M           31000000
# 16                $5M            5000000
# 17  $24.6 million CAD           18139000
# 18              $1.6M            1600000
# 19      $17.4 million           17400000
# 20           CAD$2.5M            1823000
# 21        $10 million           10000000
# 22     $5 million CAD            3653000
# 23           US$13.2M           13200000
# 24              $2.5M            2500000
# 25              $2.5m            2500000
#
#                                           Source Urls
# 0   https://www.tradefinanceglobal.com/posts/trafi...
# 1   https://realassets.ipe.com/news/aviva-among-le...
# 2   https://www.innovationnewsnetwork.com/zenobe-a...
# 3   https://www.globenewswire.com/news-release/202...
# 4   https://www.defenseworld.net/2024/04/11/chevy-...
# 5   https://www.mercomindia.com/funding-and-ma-rou...
# 6   https://www.prnewswire.com/news-releases/runwa...
# 7   https://iteuropa.com/news/large-language-model...
# 8   https://www.arabianbusiness.com/industries/tec...
# 9   https://www.biometricupdate.com/202404/ey-secu...
# 10  https://www.geekwire.com/2024/seattle-startup-...
# 11  https://www.investing.com/news/stock-market-ne...
# 12  https://tech.eu/2024/07/16/syntetica-raises-eu...
# 13  https://thebrakereport.com/eib-funds-zf-brakin...
# 14  https://www.finsmes.com/2024/06/spare-receives...
# 15  https://www.explorebit.io/article/e-Zinc%20Rai...
# 16  https://www.prweb.com/releases/biointelligence...
# 17  https://betakit.com/government-software-provid...
# 18  https://www.newswire.ca/news-releases/heylist-...
# 19  https://qohash.com/qohash-secures-17-4-million...
# 20  https://www.finsmes.com/2024/06/topicflow-rais...
# 21  https://www.marketscreener.com/quote/stock/CAN...
# 22  https://betakit.com/biointelligence-technologi...
# 23  https://financialpost.com/globe-newswire/gaiia...
# 24  https://www.finsmes.com/2024/05/sinn-studio-ra...
# 25  https://www.streetinsider.com/Accesswire/Topic...

# %% [markdown]
# Transformation
#
# Label Encoding

# %%
df ['Website Domain']. unique()
# Out:
# array(['trafigura.com', 'zenobe.com', 'canva.com', 'fidelity.com',
#        'swtchenergy.com', 'carnow.com', 'databricks.com', 'anthropic.com',
#        'ey.com', 'openpipe.ai', 'syntetica.co', 'zf.com', 'sparelabs.com',
#        'e-zinc.ca', 'biointelligence.com', 'claritisoftware.com',
#        'heylist.com', 'qohash.com', 'topicflow.com', 'gaiia.com',
#        'sinnstudio.com'], dtype=object)

# %%
df ['Financing Type Normalized'].unique()
# Out:
# array(['seed', 'series_b', 'series_i', 'series_a2', 'series_a'],
#       dtype=object)

# %%
df ['Investors'].unique()
# Out:
# array(['accelia.vc',
#        'avivainvestors.com, lloydsbankinggroup.com, santander.co.uk, swip.com, cibc.com, societegenerale.com, natwest.us, rabobank.com, mufg.jp',
#        'stackcapitalgroup.com', 'chevychasetrust.com',
#        'alantra.com, blueearth.capital', 'runwaygrowth.com',
#        'damachotelsandresorts.com', 'surocap.com', 'eib.org',
#        'vistaragrowth.com', 'edc.ca, desjardinscapital.com, fondsftq.com',
#        'cibc.com', 'inovia.vc'], dtype=object)

# %%
df ['Categories'].unique()
# Out:
# array(['[]', '["private_equity"]', '["series_b", "venture"]',
#        '["debt_financing"]', '["series_i", "venture"]',
#        '["seed", "venture"]', '["series_a2", "venture"]',
#        '["series_a", "venture"]', '["private_equity", "venture"]'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encode = LabelEncoder()

# %%
# List of categorical columns to encode
categorical_cols = ['Website Domain', 'Financing Type Normalized', 'Investors', 'Categories']

# Apply Label encoding to each categorical column
for col in categorical_cols:
    df[col] = label_encode.fit_transform(df[col])

# %%
df
# Out:
#     Website Domain                   Found At  Financing Type Normalized  \
# 0               18  2024-03-14T01:00:00+01:00                          0
# 1               19  2024-05-31T02:00:00+02:00                          0
# 2               19  2024-07-24T02:00:00+02:00                          0
# 3                2  2024-05-01T02:00:00+02:00                          0
# 4                8  2024-04-11T02:00:00+02:00                          0
# 5               15  2024-04-24T02:00:00+02:00                          3
# 6                3  2024-04-16T02:00:00+02:00                          0
# 7                5  2024-08-07T02:00:00+02:00                          4
# 8                0  2024-07-08T02:00:00+02:00                          0
# 9                7  2024-04-18T02:00:00+02:00                          0
# 10              11  2024-03-26T01:00:00+01:00                          0
# 11               2  2024-05-09T02:00:00+02:00                          0
# 12              16  2024-07-16T02:00:00+02:00                          0
# 13              20  2024-07-15T02:00:00+02:00                          0
# 14              14  2024-06-05T02:00:00+02:00                          0
# 15               6  2024-06-27T02:00:00+02:00                          2
# 16               1  2024-04-25T02:00:00+02:00                          0
# 17               4  2024-04-10T02:00:00+02:00                          0
# 18              10  2024-06-18T02:00:00+02:00                          0
# 19              12  2024-04-24T02:00:00+02:00                          0
# 20              17  2024-06-25T02:00:00+02:00                          0
# 21               4  2024-06-26T02:00:00+02:00                          0
# 22               1  2024-04-30T02:00:00+02:00                          0
# 23               9  2024-06-27T02:00:00+02:00                          1
# 24              13  2024-05-22T02:00:00+02:00                          0
# 25              17  2024-06-25T02:00:00+02:00                          0
#
#     Categories  Investors  Investors Count             Amount  \
# 0            8          0         1.846154              $1.9b
# 1            8          2         9.000000     $522.7 million
# 2            2          0         1.846154             £41.7m
# 3            8         10         1.000000       US$8 million
# 4            8          3         1.000000      $1.96 million
# 5            6          1         2.000000      $27.2 Million
# 6            0          9         1.000000        $40 million
# 7            7          0         1.846154       $685 million
# 8            8          5         1.000000              $50mn
# 9            8          0         1.846154           AU$10.7M
# 10           3          0         1.846154       $6.7 million
# 11           8         11         1.000000         $2 billion
# 12           3          0         1.846154       Û4.2 million
# 13           8          7         1.000000       Û425 million
# 14           8          0         1.846154               $10M
# 15           5          0         1.846154            USD 31M
# 16           8          0         1.846154                $5M
# 17           2         12         1.000000  $24.6 million CAD
# 18           2          0         1.000000              $1.6M
# 19           2          6         3.000000      $17.4 million
# 20           3          0         1.846154           CAD$2.5M
# 21           2          4         1.000000        $10 million
# 22           3          0         1.846154     $5 million CAD
# 23           4          8         1.000000           US$13.2M
# 24           1          0         1.846154              $2.5M
# 25           8          0         1.846154              $2.5m
#
#     Amount Normalized                                        Source Urls
# 0          1900000000  https://www.tradefinanceglobal.com/posts/trafi...
# 1           522700000  https://realassets.ipe.com/news/aviva-among-le...
# 2            53671000  https://www.innovationnewsnetwork.com/zenobe-a...
# 3             8000000  https://www.globenewswire.com/news-release/202...
# 4             1960000  https://www.defenseworld.net/2024/04/11/chevy-...
# 5            27200000  https://www.mercomindia.com/funding-and-ma-rou...
# 6            40000000  https://www.prnewswire.com/news-releases/runwa...
# 7           685000000  https://iteuropa.com/news/large-language-model...
# 8            50000000  https://www.arabianbusiness.com/industries/tec...
# 9             6865000  https://www.biometricupdate.com/202404/ey-secu...
# 10            6700000  https://www.geekwire.com/2024/seattle-startup-...
# 11         2000000000  https://www.investing.com/news/stock-market-ne...
# 12            4581000  https://tech.eu/2024/07/16/syntetica-raises-eu...
# 13          464695000  https://thebrakereport.com/eib-funds-zf-brakin...
# 14           10000000  https://www.finsmes.com/2024/06/spare-receives...
# 15           31000000  https://www.explorebit.io/article/e-Zinc%20Rai...
# 16            5000000  https://www.prweb.com/releases/biointelligence...
# 17           18139000  https://betakit.com/government-software-provid...
# 18            1600000  https://www.newswire.ca/news-releases/heylist-...
# 19           17400000  https://qohash.com/qohash-secures-17-4-million...
# 20            1823000  https://www.finsmes.com/2024/06/topicflow-rais...
# 21           10000000  https://www.marketscreener.com/quote/stock/CAN...
# 22            3653000  https://betakit.com/biointelligence-technologi...
# 23           13200000  https://financialpost.com/globe-newswire/gaiia...
# 24            2500000  https://www.finsmes.com/2024/05/sinn-studio-ra...
# 25            2500000  https://www.streetinsider.com/Accesswire/Topic...

# %%
# Reconfirming the percentage of missing values in columns
missing_percentage = df.isnull().sum() / len(df) * 100
missing_percentage
# Out:
# Website Domain               0.0
# Found At                     0.0
# Financing Type Normalized    0.0
# Categories                   0.0
# Investors                    0.0
# Investors Count              0.0
# Amount                       0.0
# Amount Normalized            0.0
# Source Urls                  0.0
# dtype: float64

# %% [markdown]
# ## Standardization

# %%
df ['Investors Count']. min()
# Out:
# 1.0

# %%
df ['Investors Count']. max()
# Out:
# 9.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
# Apply MinMaxScaler to the Investor count column
df['Investors Count'] = scaler.fit_transform(df[['Investors Count']])
df
# Out:
#     Website Domain                   Found At  Financing Type Normalized  \
# 0               18  2024-03-14T01:00:00+01:00                          0
# 1               19  2024-05-31T02:00:00+02:00                          0
# 2               19  2024-07-24T02:00:00+02:00                          0
# 3                2  2024-05-01T02:00:00+02:00                          0
# 4                8  2024-04-11T02:00:00+02:00                          0
# 5               15  2024-04-24T02:00:00+02:00                          3
# 6                3  2024-04-16T02:00:00+02:00                          0
# 7                5  2024-08-07T02:00:00+02:00                          4
# 8                0  2024-07-08T02:00:00+02:00                          0
# 9                7  2024-04-18T02:00:00+02:00                          0
# 10              11  2024-03-26T01:00:00+01:00                          0
# 11               2  2024-05-09T02:00:00+02:00                          0
# 12              16  2024-07-16T02:00:00+02:00                          0
# 13              20  2024-07-15T02:00:00+02:00                          0
# 14              14  2024-06-05T02:00:00+02:00                          0
# 15               6  2024-06-27T02:00:00+02:00                          2
# 16               1  2024-04-25T02:00:00+02:00                          0
# 17               4  2024-04-10T02:00:00+02:00                          0
# 18              10  2024-06-18T02:00:00+02:00                          0
# 19              12  2024-04-24T02:00:00+02:00                          0
# 20              17  2024-06-25T02:00:00+02:00                          0
# 21               4  2024-06-26T02:00:00+02:00                          0
# 22               1  2024-04-30T02:00:00+02:00                          0
# 23               9  2024-06-27T02:00:00+02:00                          1
# 24              13  2024-05-22T02:00:00+02:00                          0
# 25              17  2024-06-25T02:00:00+02:00                          0
#
#     Categories  Investors  Investors Count             Amount  \
# 0            8          0         0.105769              $1.9b
# 1            8          2         1.000000     $522.7 million
# 2            2          0         0.105769             £41.7m
# 3            8         10         0.000000       US$8 million
# 4            8          3         0.000000      $1.96 million
# 5            6          1         0.125000      $27.2 Million
# 6            0          9         0.000000        $40 million
# 7            7          0         0.105769       $685 million
# 8            8          5         0.000000              $50mn
# 9            8          0         0.105769           AU$10.7M
# 10           3          0         0.105769       $6.7 million
# 11           8         11         0.000000         $2 billion
# 12           3          0         0.105769       Û4.2 million
# 13           8          7         0.000000       Û425 million
# 14           8          0         0.105769               $10M
# 15           5          0         0.105769            USD 31M
# 16           8          0         0.105769                $5M
# 17           2         12         0.000000  $24.6 million CAD
# 18           2          0         0.000000              $1.6M
# 19           2          6         0.250000      $17.4 million
# 20           3          0         0.105769           CAD$2.5M
# 21           2          4         0.000000        $10 million
# 22           3          0         0.105769     $5 million CAD
# 23           4          8         0.000000           US$13.2M
# 24           1          0         0.105769              $2.5M
# 25           8          0         0.105769              $2.5m
#
#     Amount Normalized                                        Source Urls
# 0          1900000000  https://www.tradefinanceglobal.com/posts/trafi...
# 1           522700000  https://realassets.ipe.com/news/aviva-among-le...
# 2            53671000  https://www.innovationnewsnetwork.com/zenobe-a...
# 3             8000000  https://www.globenewswire.com/news-release/202...
# 4             1960000  https://www.defenseworld.net/2024/04/11/chevy-...
# 5            27200000  https://www.mercomindia.com/funding-and-ma-rou...
# 6            40000000  https://www.prnewswire.com/news-releases/runwa...
# 7           685000000  https://iteuropa.com/news/large-language-model...
# 8            50000000  https://www.arabianbusiness.com/industries/tec...
# 9             6865000  https://www.biometricupdate.com/202404/ey-secu...
# 10            6700000  https://www.geekwire.com/2024/seattle-startup-...
# 11         2000000000  https://www.investing.com/news/stock-market-ne...
# 12            4581000  https://tech.eu/2024/07/16/syntetica-raises-eu...
# 13          464695000  https://thebrakereport.com/eib-funds-zf-brakin...
# 14           10000000  https://www.finsmes.com/2024/06/spare-receives...
# 15           31000000  https://www.explorebit.io/article/e-Zinc%20Rai...
# 16            5000000  https://www.prweb.com/releases/biointelligence...
# 17           18139000  https://betakit.com/government-software-provid...
# 18            1600000  https://www.newswire.ca/news-releases/heylist-...
# 19           17400000  https://qohash.com/qohash-secures-17-4-million...
# 20            1823000  https://www.finsmes.com/2024/06/topicflow-rais...
# 21           10000000  https://www.marketscreener.com/quote/stock/CAN...
# 22            3653000  https://betakit.com/biointelligence-technologi...
# 23           13200000  https://financialpost.com/globe-newswire/gaiia...
# 24            2500000  https://www.finsmes.com/2024/05/sinn-studio-ra...
# 25            2500000  https://www.streetinsider.com/Accesswire/Topic...

# %%
df ['Investors Count']. min()
# Out:
# 0.0

# %%
df ['Investors Count']. max()
# Out:
# 1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Website Domain             26 non-null     int64
#  1   Found At                   26 non-null     object
#  2   Financing Type Normalized  26 non-null     int64
#  3   Categories                 26 non-null     int64
#  4   Investors                  26 non-null     int64
#  5   Investors Count            26 non-null     float64
#  6   Amount                     26 non-null     object
#  7   Amount Normalized          26 non-null     int64
#  8   Source Urls                26 non-null     object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 2.0+ KB
